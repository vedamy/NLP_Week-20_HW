# %% [markdown]
# # Week-20 Assignment Homework

# %% [markdown]
# 1.	Write a python program (not a Jupyter notebook, but a py file you run from the command line) that accepts the cats_txt.txt file as input and counts the frequency of all words and punctuation in that text file, ordered by frequency. Make sure to handle capital and lowercase versions of words and count them together.
# 2.	Document how to run the program you created in question 1 in a readme.md file in your repo. Be as clear as possible. Use proper markdown, and consider using screenshots. Be sure to briefly discuss why this kind of exercise might be helpful for NLP in your markdown

# %% [markdown]
# In a Jupyter notebook:
#
# 3.	Load the tokenized Paradise Lost from the Gutenberg Corpus in NLTK.* https://www.nltk.org/book/ch02.html . Stem or lemmatize the words and find counts. Select the top 20 words and create a histogram. Exclude stop words and make sure you are including words of all capitalizations in your count. If there are any meaningless “words” (“thus” and single letters, etc.) that are produced in your list or top words, alter your logic to exclude them. Specify why you chose stemming or lemmatization.

# %%
# %%HTML
# <style>
# .container { width:70% }
# </style>
# Out:
# <style>
# .container { width:70% }
# </style>

# %%
import nltk

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import regexp_tokenize, TweetTokenizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
# Show the titles of those books that are part of the gutenberg corpus
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
# Retrieve the book "Paradise Lost" by John Milton.
paradise_lost = nltk.corpus.gutenberg.raw('milton-paradise.txt')

# %%
#numbers of words
paradise_lost = [w.lower() for w in gutenberg.words('milton-paradise.txt') if w[0].isalpha()]
len(paradise_lost)
# Out:
# 80493

# %%
text_sentences = nltk.corpus.gutenberg.sents('milton-paradise.txt')
print(text_sentences)
# Out:
# [['[', 'Paradise', 'Lost', 'by', 'John', 'Milton', '1667', ']'], ['Book', 'I'], ...]

# %%
text_words = nltk.corpus.gutenberg.words('milton-paradise.txt')
print(text_words)
# Out:
# ['[', 'Paradise', 'Lost', 'by', 'John', 'Milton', ...]

# %%
#stop words are common words that we want to get rid of them
# nltk.download('stopwords')
stop_words = set(nltk.corpus.stopwords.words('english'))

# %%
# converting into lower case
low_case = [i.lower() for i in text_words]

# %%
# stop words are common words that we want to get rid of them
remove_sw = [i for i in low_case if i not in stop_words]

# %% [markdown]
# ### Lemmatizer

# %%
# import libraries
from nltk.stem import WordNetLemmatizer
from collections import Counter

# Instantiating WordNetLemmatizer
wnl = WordNetLemmatizer()

lemma_sentence = [wnl.lemmatize(i) for i in remove_sw]
# Frequency count of most common words
freq_count_words = Counter(lemma_sentence)
print(freq_count_words.most_common(20))
# Out:
# [(',', 10198), (';', 2317), ('.', 1254), (':', 748), ("'", 595), ('heaven', 436), ('thou', 432), ('thy', 414), ('thee', 358), ('-', 334), ('thus', 318), ('god', 316), ('?', 301), ('shall', 283), ('!', 251), ('yet', 228), ('earth', 217), ('though', 217), ('u', 187), ('man', 176)]

# %% [markdown]
# ### Stemmer

# %%
from nltk.stem.snowball import SnowballStemmer

# Instantiating stemmer
stemmer = SnowballStemmer(language = 'english')

stem_sent = [stemmer.stem(i) for i in remove_sw]
# Frequency count of most common words
freq_count_words = Counter(stem_sent)
print(freq_count_words.most_common(20))
# Out:
# [(',', 10198), (';', 2317), ('.', 1254), (':', 748), ("'", 595), ('heaven', 485), ('thou', 432), ('thi', 414), ('thee', 358), ('-', 334), ('thus', 318), ('god', 316), ('?', 301), ('shall', 283), ('!', 251), ('earth', 228), ('yet', 228), ('though', 217), ('us', 187), ('man', 178)]

# %% [markdown]
#  From both the results i can't see much difference between them but i see a little change in count between the words. However i choose to go with lemmatizer

# %% [markdown]
# Most of them includes punctuations and some meaninglss words, lets get rid all of them and see the results.

# %%
# will go with using isalnum() which is used to get alpha numeric characters
alpha_num = [i for i in lemma_sentence if i.isalnum()]

# Remove all the meaningless words
meaningless_words = ['thus', 'th', 'u', 'though', 'thou', 'yet', 'thee', 'thy']
words = [i for i in alpha_num if i not in meaningless_words]

# %%
wnl = WordNetLemmatizer()

lemma_sentence = [wnl.lemmatize(i) for i in words]
freq_count_words = Counter(lemma_sentence)
print(freq_count_words.most_common(20))
# Out:
# [('heaven', 436), ('god', 316), ('shall', 283), ('earth', 217), ('man', 176), ('first', 175), ('day', 157), ('high', 153), ('one', 142), ('son', 132), ('far', 129), ('death', 127), ('may', 126), ('power', 125), ('great', 123), ('till', 120), ('like', 120), ('world', 119), ('hell', 119), ('thing', 116)]

# %%
freq_words = freq_count_words.most_common(20)
words, frequency =zip(*freq_words)
print(words, frequency)
# Out:
# ('heaven', 'god', 'shall', 'earth', 'man', 'first', 'day', 'high', 'one', 'son', 'far', 'death', 'may', 'power', 'great', 'till', 'like', 'world', 'hell', 'thing') (436, 316, 283, 217, 176, 175, 157, 153, 142, 132, 129, 127, 126, 125, 123, 120, 120, 119, 119, 116)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 10))
plt.bar(words, frequency)
plt.xlabel('Most common words')
plt.ylabel('Total count')
plt.show()

# %% [markdown]
# 4.	Perform Vader Sentiment Analysis on the book. Find the 5 most negative, 5 most positive, and 5 most neutral sentences in Paradise Lost*. http://www.nltk.org/howto/sentiment.html . This may take a while to run, so you can always start with a small subset of the data (100 sentences) and then once your code works as expected, expand it to the whole book and let it run.

# %%
import nltk
import pandas as pd

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\rsagu\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

read = nltk.corpus.gutenberg.open('milton-paradise.txt')

sentiments = []
for line in read:
    sentiment = analyzer.polarity_scores(line)
    compound = sentiment['compound']
    pos = sentiment['pos']
    neu = sentiment['neu']
    neg = sentiment['neg']

    sentiments.append({
                "text":line,
                "compound":compound,
                "positive":pos,
                "negative":neg,
                "neutral":neu
})
    
sentiments_df = pd.DataFrame(sentiments)

print("Top 5 Positive Sentences")
sentiments_df.sort_values('positive', ascending=False)[['text','positive']].head()
# Out:
# Top 5 Positive Sentences
#                                                    text  positive
# 1571       I pleased, and with attractive graces won \n     0.858
# 608      Of dauntless courage, and considerate pride \n     0.855
# 7267     She fair, divinely fair, fit love for Gods! \n     0.838
# 2211  With joy and peace triumphing, and fair truth. \n     0.835
# 6299           Intelligence of Heaven, Angel serene! \n     0.829

# %%
sentiments_df.sort_values('negative', ascending=False)[['text','negative']].head()
# Out:
#                                                text  negative
# 5406   Exhausted, spiritless, afflicted, fallen. \n     1.000
# 916      Desperate revenge, and battle dangerous \n     0.919
# 510       Exposed a matron, to avoid worse rape. \n     0.850
# 1305     O shame to men! Devil with devil damned \n     0.831
# 10381  On penalty of death, and suffering death; \n     0.822

# %%
sentiments_df.sort_values('neutral', ascending=False)[['text','neutral']].head()
# Out:
#                                                    text  neutral
# 5317       Sat eagle-winged; beside him hung his bow \n      1.0
# 5762          Capacious bed of waters:  Thither they \n      1.0
# 5777    All but within those banks, where rivers now \n      1.0
# 5775       And on the washy oose deep channels wore; \n      1.0
# 5774  With serpent errour wandering, found their way...      1.0

# %% [markdown]
#  5.	Explain your findings from the previous question. Are the sentences and their sentiment analysis scores correct? Explain why or why not.

# %% [markdown]
# From the above Vader Sentiment Analysis on the book namely, "Paradise Lost", we can analyse the top 5 Positive,
# negative and neutal sentences. From my knowledge, i see all the negative words like[revenge, suffering, death, worse] falls
# under the top 5 negative sentences and positive words like[courage, won, divinely, love, gods] falls under the positive
# sentence, and neutral words like[bed of waters, rivers, washy] comes in neutal sentences.
# From this we can say that Vader Sentiment Analysis was able to correctly distinguish between positive, negative and neutarl sentences.

# %% [markdown]
# ![Introduction%20to%20NLP.jpg](attachment:Introduction%20to%20NLP.jpg)
